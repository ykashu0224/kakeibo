# %% [markdown]
# <a href="https://colab.research.google.com/github/ykashu0224/kakeibo/blob/main/kakeibo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
df= pd.read_csv('drive/My Drive/kakeibo/kakei.csv')
# df= pd.read_csv('drive/My Drive/kakeibo/kakei.csv', encoding='shift_jis')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
y=df['income']
x=df['sum_expence']
# Out:
# 0     187298
# 1     164653
# 2     158970
# 3     161027
# 4     200218
# 5     197040
# 6     195784
# 7     189268
# 8     188532
# 9     164412
# 10    167642
# 11    259690
# 12    221843
# 13    220716
# 14    188931
# 15    253186
# 16    190458
# 17    442862
# 18    205897
# 19    157080
# 20    167080
# Name: sum_expence, dtype: int64

# %%
plt.scatter(x, y)
plt.show()

# %%
df.describe()
# Out:
#               year      month  current_saving         income     income_add  \
# count    21.000000  21.000000    2.100000e+01      21.000000       2.000000
# mean   2022.476190   6.285714    9.551388e+05  241504.523810  201296.000000
# std       0.511766   3.195980    3.401372e+05   20251.437797  228106.990757
# min    2022.000000   1.000000    4.520000e+05  218000.000000   40000.000000
# 25%    2022.000000   4.000000    6.600920e+05  218000.000000  120648.000000
# 50%    2022.000000   6.000000    9.807640e+05  246000.000000  201296.000000
# 75%    2023.000000   9.000000    1.113018e+06  253727.000000  281944.000000
# max    2023.000000  12.000000    1.612898e+06  282000.000000  362592.000000
#
#           add_saving    sum_expence  life_fee       家賃    臨時出費_生活費赤字  ...  \
# count      21.000000      21.000000      21.0     21.0      7.000000  ...
# mean    55280.857143  203932.714286   80000.0  55000.0  38657.142857  ...
# ...

# %%
dfc=df-df.mean()
# Out:
# <ipython-input-15-deb3e7aea27b>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfc=df-df.mean()

# %%
dfc.describe()
# Out:
#          add_saving  current_saving        income     income_add  life_fee  \
# count  2.100000e+01    2.100000e+01  2.100000e+01       2.000000      21.0
# mean  -3.464742e-12    4.434869e-11 -6.929483e-12       0.000000       0.0
# std    4.446980e+04    3.401372e+05  2.025144e+04  228106.990757       0.0
# min   -6.897086e+04   -5.031388e+05 -2.350452e+04 -161296.000000       0.0
# 25%   -3.306486e+04   -2.950468e+05 -2.350452e+04  -80648.000000       0.0
# 50%   -1.933857e+03    2.562519e+04  4.495476e+03       0.000000       0.0
# 75%    2.307714e+04    1.578792e+05  1.222248e+04   80648.000000       0.0
# max    1.348451e+05    6.577592e+05  4.049548e+04  161296.000000       0.0
#
#               month   sum_expence          wifi          year         クレカ合計  \
# count  2.100000e+01  2.100000e+01  2.100000e+01  2.100000e+01  2.100000e+01
# mean   2.114711e-16 -4.157690e-12 -1.732371e-13  1.082732e-13 -6.929483e-13
# ...

# %%
y=dfc['sum_expence']
x=dfc['income']

# %%
plt.scatter(x,y)

# %%
xx=x*x
xy=x*y
a=xy.sum()/xx.sum()
a
# Out:
# 1.1045856078670397

# %%
plt.scatter(x,y)
plt.plot(x*a*y)
